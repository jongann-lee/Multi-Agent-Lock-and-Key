# %% [markdown]
# Let's first visualize the downloaded DEM file

# %%
import sys
import os

project_root = os.path.abspath(os.path.join(os.getcwd(), ".."))

# Add it to sys.path if it isn't there already
if project_root not in sys.path:
    sys.path.append(project_root)

import rasterio
import matplotlib.pyplot as plt
import numpy as np

from rasterio.enums import Resampling

def get_grid_from_local_dem(file_path, n_size):
    """
    Automatically detects bounds from a local 1m DEM and 
    resamples it to an N x N grid.
    """
    with rasterio.open(file_path) as dataset:
        # 1. Automatically get metadata/bounds
        bounds = dataset.bounds
        crs = dataset.crs
        print(f"File Bounds: {bounds}")
        print(f"Coordinate System: {crs}")

        # 2. Resample during read (Memory efficient)
        # We specify the output shape as (1, n_size, n_size) for (band, height, width)
        data = dataset.read(
            1,
            out_shape=(n_size, n_size),
            resampling=Resampling.bilinear # Or Resampling.max to preserve peaks
        )
        
        # 3. Handle NoData values (common in 1m DEMs)
        if dataset.nodata is not None:
            data = np.where(data == dataset.nodata, np.nan, data)

        return data, bounds

# --- Execution ---
# Replace with your West Virginia file path
dem_path = 'WV_DEM.tif' 
N = 64

height_grid, dem_bounds = get_grid_from_local_dem(dem_path, N)

# Visualization
plt.figure(figsize=(8, 6))
plt.imshow(height_grid, cmap='terrain', extent=[dem_bounds.left, dem_bounds.right, dem_bounds.bottom, dem_bounds.top])
plt.colorbar(label='Elevation (meters)')
plt.title(f"{N}x{N} Abstraction of 1m DEM")
plt.xlabel("Longitude / Easting")
plt.ylabel("Latitude / Northing")
plt.show()
# Out:
# File Bounds: BoundingBox(left=446320.0, bottom=4238528.000032917, right=449477.0, top=4241739.000032917)
# Coordinate System: EPSG:26917

# %% [markdown]
# Let's now visualize the corresponding graph

# %%
from real_map_generation import RealTerrainGrid
import networkx as nx
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors
import matplotlib.patches as patches
import matplotlib.collections as mc
import numpy as np
import pickle
import os

# Rotate clockwise 90 degrees to counteract the anticlockwise shift
corrected_height_grid = np.rot90(height_grid, k=-1)

# Load road data if available
road_nodes = set()
road_edges = set()
road_pkl = "WV_roads.pkl"
if os.path.exists(road_pkl):
    with open(road_pkl, "rb") as f:
        road_data = pickle.load(f)
    road_nodes = road_data["road_nodes"]
    road_edges = road_data["road_edges"]
    print(f"Loaded {len(road_nodes)} road nodes and {len(road_edges)} road edges")
else:
    print(f"No road data found at {road_pkl}. Run download_roads.py first.")

target1 = (14,54)
target2 = (1,29)
target3 = (33,17)
target4 = (34,35)
target5 = (63,37)
target6 = (37, 5)
target7 = (49, 58)

graph_generator = RealTerrainGrid(corrected_height_grid, source=(0,0), targets=[target1, target2, target3, target4, target5, target6, target7], 
                                  k_up=1.0, k_down=2.0, road_nodes=road_nodes, road_edges=road_edges)

graph_generator.compute_all_visibilities()
env_graph = graph_generator.get_graph().copy()

# Note that for some reason the x and y axes are flipped
graph_generator.add_obstacle(center=(47,43), rx=5, ry=3)

graph_generator.add_obstacle(center=(30,36), rx=3, ry=5)
graph_generator.add_obstacle(center=(31,14), rx=4, ry=4)
graph_generator.add_obstacle(center=(36,55), rx=5, ry=3)
graph_generator.add_obstacle(center=(14,17), rx=4, ry=4)

blocked_env_graph = graph_generator.get_graph().copy()
# Out:
# Loaded 821 road nodes and 2010 road edges

# %% [markdown]
# ### Road Overlay Visualization

# %%
# --- Visualize road edges on top of the terrain ---
pos = nx.get_node_attributes(blocked_env_graph, 'pos')
all_heights = [d.get('height', 0) for _, d in blocked_env_graph.nodes(data=True)]
max_height = max(all_heights) if all_heights else 1
norm = mcolors.Normalize(vmin=0, vmax=max_height + 1)
cmap_terrain = plt.cm.terrain

xs = sorted(set(p[0] for p in pos.values()))
ys = sorted(set(p[1] for p in pos.values()))
cell_w = xs[1] - xs[0]
cell_h = ys[1] - ys[0]

fig, ax = plt.subplots(figsize=(10, 10))

# Terrain squares (obstacles black; everything else by height — source/targets
# get markers on top so the cell underneath is plain terrain)
for node, data in blocked_env_graph.nodes(data=True):
    x, y = pos[node]
    if data.get("type") == "obstacle":
        color = "black"
    else:
        color = cmap_terrain(norm(data.get('height', 0)))
    ax.add_patch(patches.Rectangle(
        (x - cell_w / 2, y - cell_h / 2), cell_w, cell_h,
        linewidth=0, facecolor=color
    ))

# Road edges in dark grey (no separate node overlay — nodes are implied)
road_segments = [[pos[u], pos[v]] for u, v, d in blocked_env_graph.edges(data=True) if d.get('is_road')]
if road_segments:
    ax.add_collection(mc.LineCollection(road_segments, colors='#404040', linewidths=2.0, zorder=4))

# Markers: source = green circle, targets = X (red unreached, grey reached)
src_pts, unreached_pts, reached_pts = [], [], []
for node, data in blocked_env_graph.nodes(data=True):
    t = data.get("type")
    if t == "source":
        src_pts.append(pos[node])
    elif t == "target_unreached":
        unreached_pts.append(pos[node])
    elif t == "target_reached":
        reached_pts.append(pos[node])

if src_pts:
    ax.scatter([p[0] for p in src_pts], [p[1] for p in src_pts],
               marker='o', s=220, facecolor='limegreen', edgecolor='darkgreen',
               linewidths=1.5, zorder=10)
if unreached_pts:
    ax.scatter([p[0] for p in unreached_pts], [p[1] for p in unreached_pts],
               marker='x', s=200, color='red', linewidths=3, zorder=10)
if reached_pts:
    ax.scatter([p[0] for p in reached_pts], [p[1] for p in reached_pts],
               marker='x', s=200, color='grey', linewidths=3, zorder=10)

ax.set_xlim(xs[0] - cell_w / 2, xs[-1] + cell_w / 2)
ax.set_ylim(ys[0] - cell_h / 2, ys[-1] + cell_h / 2)
ax.set_aspect('equal')
ax.axis('off')
plt.title("Terrain with Road Overlay")
plt.tight_layout()
plt.show()

num_road_nodes = sum(1 for _, d in blocked_env_graph.nodes(data=True) if d.get('is_road'))
num_road_edges = sum(1 for _, _, d in blocked_env_graph.edges(data=True) if d.get('is_road'))
print(f"Road nodes in graph: {num_road_nodes}, Road edges in graph: {num_road_edges}")
# Out:
# Road nodes in graph: 821, Road edges in graph: 2010

# %%
# --- 0. Select the Observer (your vision viewpoint) ---
observer_node = (44, 47) 

# Retrieve visible edges as sorted tuples for lookup
visible_set = []
# visible_set = set(tuple(sorted(e)) for e in env_graph.nodes[observer_node].get("visible_edges", []))

# 1. Setup Data for Plotting
pos = nx.get_node_attributes(env_graph, 'pos')
edge_labels = nx.get_edge_attributes(env_graph, 'distance')  # Or compute if missing
formatted_edge_labels = {k: f"{v:.1f}" for k, v in edge_labels.items()}

# 2. Setup Colormap for Heights
all_heights = [data.get('height', 0) for _, data in env_graph.nodes(data=True)]
max_height = max(all_heights) if all_heights else 1
norm = mcolors.Normalize(vmin=0, vmax=max_height + 1)
cmap = plt.cm.terrain

# 3. Build Node Color List
color_map = []
for node, data in env_graph.nodes(data=True):
    node_type = data.get("type", "intermediate")
    if node_type == "source":
        color_map.append("limegreen")  
    elif node_type == "target_unreached":
        color_map.append("cyan")
    # elif node == observer_node:
    #     color_map.append("black")
    elif node_type == "obstacle":
        color_map.append("black")
    else:
        h = data.get('height', 0)
        rgba_color = cmap(norm(h))
        color_map.append(rgba_color)

# 4. Edge Colors (gold for visible from observer)
edge_color_map = []
for u, v in env_graph.edges():
    edge_key = tuple(sorted((u, v)))
    if edge_key in visible_set:
        edge_color_map.append('gold')
    else:
        edge_color_map.append('gray')

# 5. Draw the Graph
plt.figure(figsize=(12, 12))
nx.draw(
    blocked_env_graph,
    pos=pos,
    node_color=color_map,
    with_labels=False,
    node_size=40,
    font_color='white',
    font_weight='bold',
    width=3.0,
    edge_color=edge_color_map,
    arrows=False
)

# Fixed: Pass the dict here
nx.draw_networkx_edge_labels(
    env_graph,
    pos,
    edge_labels=False,  
    font_size=8,
    label_pos=0.5
)

plt.title(f"Terrain Grid Graph: Heights")
plt.axis('off')
plt.tight_layout()
plt.show()
# Out:
# /var/folders/sz/hz_r9sdd0978ddwt1zk8pj8m0000gn/T/ipykernel_32636/3667378278.py:71: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()

# %%
from Graph_Generation.target_graph import create_fully_connected_target_graph

source = [node for node, data in env_graph.nodes(data=True) if data.get('type') == "source"][0]
targets = [node for node, data in env_graph.nodes(data=True) if data.get('type') == "target_unreached"]

target_graph = create_fully_connected_target_graph(env_graph, source=source, targets=targets, num_neighbors=3, recursions=2, num_obstacles=3, obstacle_hop=4)

# --- 1. Prepare for Plotting ---

edge_labels = {}
for u, v, data in target_graph.edges(data=True):
    distance = data['distance']
    edge_labels[(u, v)] = f"{distance:.2f}"

# --- 2. Create Dynamic Edge Styles for the Sparse Grid ---

edge_widths = []
edge_styles = []
for u, v, data in env_graph.edges(data=True):
    num_used = data.get('num_used', 0)
    if num_used > 0:
        # Style for used edges: solid and thicker based on usage count
        edge_styles.append('solid')
        edge_widths.append(1.0 + 7.0 * num_used)  # Scaled for visibility
    else:
        # Style for unused edges: dotted and thin
        edge_styles.append('dotted')
        edge_widths.append(0.1)

# --- Create the Single Plot (Sparse Grid) ---

# Set the figure size to 12x12
plt.figure(figsize=(12, 12))

# Set the title
plt.title("Sparse Grid (Edge Thickness = Usage)")

# Draw the Sparse Grid with the existing parameters
nx.draw(
    env_graph,
    pos=pos,
    node_color=color_map,
    with_labels=False,
    node_size=10,
    width=edge_widths,  # Use the dynamic widths
    style=edge_styles,   # Use the dynamic styles
    arrows=False
)

plt.tight_layout()
plt.show()

# %% [markdown]
# Remove the obstacle edges entirely

# %%
# Remove all edges connected to obstacle nodes from the blocked_env_graph
edges_to_remove = [(u, v) for u, v in blocked_env_graph.edges() 
                   if blocked_env_graph.nodes[u].get('type') == 'obstacle' 
                   or blocked_env_graph.nodes[v].get('type') == 'obstacle']

blocked_env_graph.remove_edges_from(edges_to_remove)

# Update the visible_edges for all nodes to reflect the removed edges
for node in blocked_env_graph.nodes():
    if "visible_edges" in blocked_env_graph.nodes[node]:
        current_visible = blocked_env_graph.nodes[node]["visible_edges"]
        # Remove any blocked edges from the visible_edges set
        updated_visible = set(current_visible) - set(edges_to_remove)
        blocked_env_graph.nodes[node]["visible_edges"] = list(updated_visible)

# %% [markdown]
# Let's see what the shortest path agent intends to do

# %%
from Single_Agent.shortest_path_agent import ShortestPathAgent

env_graph1 = env_graph.copy()  # Agent's world model (doesn't know any edges are blocked)
source = (N-1, N-1)
SPP_Agent = ShortestPathAgent(env_graph1,
                              target_graph_num_neighbors=4,
                              target_graph_recursions=2,
                              target_graph_obstacle_hop=4,
                              target_graph_num_obstacles=3)
path_1 = SPP_Agent.generate_path(source)
path_1_original = path_1.copy()

current_node = path_1[0]
index = 0

while index < len(path_1) - 1:
    next_node = path_1[index + 1]

    # Mark target as reached when we arrive at it
    if env_graph1.nodes[current_node].get('type') == "target_unreached":
        env_graph1.nodes[current_node]['type'] = "target_reached"

    # Check out all the observable edges
    observable_edges = set(blocked_env_graph.nodes[current_node]["visible_edges"])
    assumed_observable_edges = set(env_graph1.nodes[current_node]["visible_edges"])
    blocked_edges = assumed_observable_edges - observable_edges

    if len(blocked_edges) > 0:
        # Remove blocked edges from agent's world model
        for edge in blocked_edges:
            u, v = edge
            if env_graph1.has_edge(u, v):
                print(f"From {current_node}, observed edge ({u}, {v}) is blocked. Removing from graph.")
                env_graph1.remove_edge(u, v)
        # Update the visibility mapping as well
        for node in env_graph1.nodes():
            if "visible_edges" in env_graph1.nodes[node]:
                current_visible = env_graph1.nodes[node]["visible_edges"]
                updated_visible = set(current_visible) - blocked_edges
                env_graph1.nodes[node]["visible_edges"] = list(updated_visible)

        # Check if any blocked edge is in our current path
        path_edges = [(path_1[i], path_1[i+1]) for i in range(index, len(path_1) - 1)]
        blocked_edges_both_directions = set()
        for u, v in blocked_edges:
            blocked_edges_both_directions.add((u, v))
            blocked_edges_both_directions.add((v, u))

        if any(edge in blocked_edges_both_directions for edge in path_edges):
            print(f"Blocked edge detected in planned path. Recalculating from {current_node}...")
            path_1 = path_1[:index + 1] + SPP_Agent.generate_path(current_node)[1:]

    # Move to the next node
    next_node = path_1[index + 1]
    print(f"Moving from {current_node} to {next_node}")
    current_node = next_node
    index += 1

# Mark the final node if it's a target
if env_graph1.nodes[current_node].get('type') == 'target_unreached':
    env_graph1.nodes[current_node]['type'] = 'target_reached'
# Out:
# /Users/jongannlee/Code/LEADCAT/Multi_Target_and_Agent_Visibility_Nav/Single_Agent/lin_kernighan_tsp.py:346: RuntimeWarning: invalid value encountered in scalar subtract
#   hamiltonian_cycle_distance - distance_matrix[a, b]
# Moving from (63, 63) to (63, 62)
# Moving from (63, 62) to (63, 61)
# Moving from (63, 61) to (63, 60)
# Moving from (63, 60) to (62, 60)
# Moving from (62, 60) to (62, 59)
# Moving from (62, 59) to (62, 58)
# Moving from (62, 58) to (62, 57)
# Moving from (62, 57) to (62, 56)
# Moving from (62, 56) to (62, 55)
# Moving from (62, 55) to (62, 54)
# Moving from (62, 54) to (62, 53)
# Moving from (62, 53) to (62, 52)
# Moving from (62, 52) to (62, 51)
# Moving from (62, 51) to (62, 50)
# Moving from (62, 50) to (62, 49)
# Moving from (62, 49) to (62, 48)
# Moving from (62, 48) to (62, 47)
# Moving from (62, 47) to (62, 46)
# Moving from (62, 46) to (62, 45)
# From (62, 45), observed edge ((61, 44), (62, 44)) is blocked. Removing from graph.
# From (62, 45), observed edge ((61, 45), (60, 45)) is blocked. Removing from graph.
# From (62, 45), observed edge ((62, 44), (61, 44)) is blocked. Removing from graph.
# From (62, 45), observed edge ((60, 45), (60, 44)) is blocked. Removing from graph.
# From (62, 45), observed edge ((61, 44), (60, 44)) is blocked. Removing from graph.
# From (62, 45), observed edge ((60, 44), (60, 45)) is blocked. Removing from graph.
# From (62, 45), observed edge ((60, 45), (61, 45)) is blocked. Removing from graph.
# From (62, 45), observed edge ((61, 45), (61, 44)) is blocked. Removing from graph.
# From (62, 45), observed edge ((61, 44), (61, 45)) is blocked. Removing from graph.
# From (62, 45), observed edge ((60, 44), (61, 44)) is blocked. Removing from graph.
# Moving from (62, 45) to (63, 45)
# From (63, 45), observed edge ((60, 44), (59, 44)) is blocked. Removing from graph.
# From (63, 45), observed edge ((59, 43), (60, 43)) is blocked. Removing from graph.
# From (63, 45), observed edge ((60, 43), (60, 44)) is blocked. Removing from graph.
# From (63, 45), observed edge ((59, 44), (60, 44)) is blocked. Removing from graph.
# From (63, 45), observed edge ((60, 43), (59, 43)) is blocked. Removing from graph.
# From (63, 45), observed edge ((59, 44), (59, 43)) is blocked. Removing from graph.
# From (63, 45), observed edge ((60, 44), (60, 43)) is blocked. Removing from graph.
# From (63, 45), observed edge ((59, 43), (59, 44)) is blocked. Removing from graph.
# Moving from (63, 45) to (63, 44)
# From (63, 44), observed edge ((59, 44), (59, 45)) is blocked. Removing from graph.
# From (63, 44), observed edge ((58, 44), (58, 43)) is blocked. Removing from graph.
# From (63, 44), observed edge ((59, 45), (60, 45)) is blocked. Removing from graph.
# From (63, 44), observed edge ((58, 44), (59, 44)) is blocked. Removing from graph.
# From (63, 44), observed edge ((61, 43), (60, 43)) is blocked. Removing from graph.
# From (63, 44), observed edge ((60, 45), (59, 45)) is blocked. Removing from graph.
# From (63, 44), observed edge ((61, 43), (61, 44)) is blocked. Removing from graph.
# From (63, 44), observed edge ((58, 43), (58, 44)) is blocked. Removing from graph.
# From (63, 44), observed edge ((58, 43), (59, 43)) is blocked. Removing from graph.
# From (63, 44), observed edge ((59, 45), (59, 44)) is blocked. Removing from graph.
# From (63, 44), observed edge ((60, 43), (61, 43)) is blocked. Removing from graph.
# From (63, 44), observed edge ((60, 46), (60, 45)) is blocked. Removing from graph.
# From (63, 44), observed edge ((61, 43), (62, 43)) is blocked. Removing from graph.
# From (63, 44), observed edge ((62, 43), (61, 43)) is blocked. Removing from graph.
# From (63, 44), observed edge ((60, 45), (60, 46)) is blocked. Removing from graph.
# From (63, 44), observed edge ((59, 43), (58, 43)) is blocked. Removing from graph.
# From (63, 44), observed edge 
) is blocked. Removing from graph.
# From (63, 41), observed edge ((57, 42), (57, 43)) is blocked. Removing from graph.
# From (63, 41), observed edge ((57, 45), (57, 46)) is blocked. Removing from graph.
# From (63, 41), observed edge ((56, 40), (55, 40)) is blocked. Removing from graph.
# From (63, 41), observed edge ((59, 42), (58, 42)) is blocked. Removing from graph.
# From (63, 41), observed edge ((55, 41), (55, 42)) is blocked. Removing from graph.
# Blocked edge detected in planned path. Recalculating from (63, 41)...
# Moving from (63, 41) to (63, 40)
# From (63, 40), observed edge ((56, 46), (56, 45)) is blocked. Removing from graph.
# From (63, 40), observed edge ((58, 46), (58, 47)) is blocked. Removing from graph.
# From (63, 40), observed edge ((56, 45), (56, 46)) is blocked. Removing from graph.
# From (63, 40), observed edge ((58, 47), (58, 46)) is blocked. Removing from graph.
# Moving from (63, 40) to (62, 40)
# From (62, 40), observed edge ((57, 39), (58, 39)) is blocked. Removing from graph.
# From (62, 40), observed edge ((58, 39), (58, 38)) is blocked. Removing from graph.
# From (62, 40), observed edge ((59, 40), (59, 39)) is blocked. Removing from graph.
# From (62, 40), observed edge ((58, 40), (58, 39)) is blocked. Removing from graph.
# From (62, 40), observed edge ((60, 38), (60, 39)) is blocked. Removing from graph.
# From (62, 40), observed edge ((56, 39), (57, 39)) is blocked. Removing from graph.
# From (62, 40), observed edge ((59, 39), (59, 38)) is blocked. Removing from graph.
# From (62, 40), observed edge ((58, 38), (59, 38)) is blocked. Removing from graph.
# From (62, 40), observed edge ((57, 39), (57, 38)) is blocked. Removing from graph.
# From (62, 40), observed edge ((60, 40), (60, 39)) is blocked. Removing from graph.
# From (62, 40), observed edge ((59, 38), (58, 38)) is blocked. Removing from graph.
# From (62, 40), observed edge ((58, 37), (58, 38)) is blocked. Removing from graph.
# From (62, 40), observed edge ((58, 39), (58, 40)) is blocked. Removing from graph.
# From (62, 40), observed edge ((56, 39), (56, 38)) is blocked. Removing from graph.
# From (62, 40), observed edge ((60, 39), (60, 38)) is blocked. Removing from graph.
# From (62, 40), observed edge ((60, 39), (61, 39)) is blocked. Removing from graph.
# From (62, 40), observed edge ((58, 38), (58, 37)) is blocked. Removing from graph.
# From (62, 40), observed edge ((59, 39), (58, 39)) is blocked. Removing from graph.
# From (62, 40), observed edge ((57, 38), (57, 39)) is blocked. Removing from graph.
# From (62, 40), observed edge ((59, 39), (59, 40)) is blocked. Removing from graph.
# From (62, 40), observed edge ((59, 38), (59, 39)) is blocked. Removing from graph.
# From (62, 40), observed edge ((58, 38), (58, 39)) is blocked. Removing from graph.
# From (62, 40), observed edge ((58, 39), (57, 39)) is blocked. Removing from graph.
# From (62, 40), observed edge ((60, 39), (59, 39)) is blocked. Removing from graph.
# From (62, 40), observed edge ((57, 39), (57, 40)) is blocked. Removing from graph.
# From (62, 40), observed edge ((58, 39), (59, 39)) is blocked. Removing from graph.
# From (62, 40), observed edge ((58, 38), (57, 38)) is blocked. Removing from graph.
# From (62, 40), observed edge ((61, 39), (60, 39)) is blocked. Removing from graph.
# From (62, 40), observed edge ((61, 40), (61, 39)) is blocked. Removing from graph.
# From (62, 40), observed edge ((61, 39), (61, 40)) is blocked. Removing from graph.
# From (62, 40), observed edge ((57, 39), (56, 39)) is blocked. Removing from graph.
# From (62, 40), observed edge ((57, 40), (57, 39)) is blocked. Removing from graph.
# From (62, 40), observed edge ((60, 39), (60, 40)) is blocked. Removing from graph.
# From (62, 40), observed edge ((56, 38), (56, 39)) is blocked. Removing from graph.
# From (62, 40), observed edge ((57, 38), (58, 38)) is blocked. Removing from graph.
# From (62, 40), observed edge ((59, 39), (60, 39)) is blocked. Removing from graph.
# Blocked edge detected in planned path. Recalculating from (62, 40)...
# Moving from (62, 40) to (62, 39)
# Moving from (62, 39) to (62, 38)
# Moving from (62, 38) to (62, 37)
# Moving from (62, 37) to (61, 37)
# Moving from (61, 37) to (60, 37)
# Moving from (60, 37) to (59, 37)
# Moving from (59, 37) to (58, 37)
# Moving from (58, 37) to (58, 36)
# Moving from (58, 36) to (58, 35)
# Moving from (58, 35) to (57, 35)
# Moving from (57, 35) to (57, 34)
# Moving from (57, 34) to (56, 34)
# Moving from (56, 34) to (55, 34)
# Moving from (55, 34) to (54, 34)
# Moving from (54, 34) to (53, 34)
# Moving from (53, 34) to (53, 33)
# Moving from (53, 33) to (52, 33)
# Moving from (52, 33) to (52, 32)
# Moving from (52, 32) to (51, 32)
# Moving from (51, 32) to (51, 31)
# Moving from (51, 31) to (50, 31)
# Moving from (50, 31) to (50, 30)
# From (50, 30), observed edge ((35, 27), (35, 28)) is blocked. Removing from graph.
# From (50, 30), observed edge ((34, 28), (33, 28)) is blocked. Removing from graph.
# From (50, 30), observed edge ((34, 30), (34, 29)) is blocked. Removing from graph.
# From (50, 30), observed edge ((38, 31), (37, 31)) is blocked. Removing from graph.
# From (50, 30), observed edge ((35, 32), (34, 32)) is blocked. Removing from graph.
# From (50, 30), observed edge ((36, 27), (37, 27)) is blocked. Removing from graph.
# From (50, 30), observed edge ((35, 28), (36, 28)) is blocked. Removing from graph.
# From (50, 30), observed edge ((35, 30), (35, 29)) is blocked. Removing from graph.
# From (50, 30), observed edge ((37, 28), (37, 29)) is blocked. Removing from graph.
# From (50, 30), observed edge ((39, 29), (39, 28)) is blocked. Removing from graph.
# From (50, 30), observed edge ((35, 33), (35, 32)) is blocked. Removing from graph.
# From (50, 30), observed edge ((38, 28), (37, 28)) is blocked. Removing from graph.
# From (50, 30), observed edge ((40, 29), (40, 30)) is blocked. Removing from graph.
# From (50, 30), observed edge ((33, 32), (32, 32)) is blocked. Removing from graph.
# From (50, 30), observed edge ((41, 30), (40, 30)) is blocked. Removing from graph.
# From (50, 30), observed edge ((38, 31), (39, 31)) is blocked. Removing from graph.
# From (50, 30), observed edge ((38, 32), (38, 33)) is blocked. Removing from graph.
# From (50, 30), observed edge ((32, 31), (31, 31)) is blocked. Removing from graph.
# From (50, 30), observed edge ((39, 27), (39, 28)) is blocked. Removing from graph.
# From (50, 30), observed edge ((33, 30), (32, 30)) is blocked. Removing from graph.
# From (50, 30), observed edge ((34, 30), (33, 30)) is blocked. Removing from graph.
# From (50, 30), observed edge ((38, 29), (39, 29)) is blocked. Removing from graph.
# From (50, 30), observed edge ((39, 30), (38, 30)) is blocked. Removing from graph.
# From (50, 30), observed edge ((36, 30), (36, 29)) is blocked. Removing from graph.
# From (50, 30), observed edge ((36, 33), (36, 32)) is blocked. Removing from graph.
# From (50, 30), observed edge ((35, 29), (35, 28)) is blocked. Removing from graph.
# From (50, 30), observed edge ((38, 28), (38, 27)) is blocked. Removing from graph.
# From (50, 30), observed edge ((41, 29), (41, 30)) is blocked. Removing from graph.
# From (50, 30), observed edge ((40, 32), (39, 32)) is blocked. Removing from graph.
# From (50, 30), observed edge ((34, 32), (34, 31)) is blocked. Removing from graph.
# From (50, 30), observed edge ((33, 31), (33, 32)) is blocked. Removing from graph.
# From (50, 30), observed edge ((38, 31), (38, 32)) is blocked. Removing from graph.
# From (50, 30), observed edge ((41, 30), (42, 30)) is blocked. Removing from graph.
# From (50, 30), observed edge ((39, 32), (39, 33)) is blocked. Removing from graph.
# From (50, 30), observed edge ((37, 32), (36, 32)) is blocked. Removing from graph.
# From (50, 30), observed edge ((38, 33), (38, 32)) is blocked. Removing from graph.
# From (50, 30), observed edge ((33, 33), (33, 32)) is blocked. Removing from graph.
# From (50, 30), observed edge ((35, 29), (35, 30)) is blocked. Removing from graph.
# From (50, 30), observed edge ((36, 29), (36, 28)) is blocked. Removing from graph.
# From (50, 30), observed edge ((36, 30), (35, 30)) is blocked. Removing from graph.
# From (50, 30), observed edge ((36, 32), (37, 32)) is blocked. Removing from graph.
# From (50, 30), observed edge ((36, 28), (36, 29)) is blocked. Removing from graph.
# From (50, 30), observed edge ((40, 28), (39, 28)) is blocked. Removing from graph.
# From (50, 30), observed edge ((37, 28), (37, 27)) is blocked. Removing from graph.
# From (50, 30), observed edge ((35, 30), (36, 30)) is blocked. Removing from graph.
# From (50, 30), observed edge ((41, 31), (41, 30)) is blocked. Removing from graph.
# From (50, 30), observed edge ((31, 30), (31, 29)) is blocked. Removing from graph.
# From (50, 30), observed edge ((33, 31), (33, 30)) is blocked. Removing from graph.
# From (50, 30), observed edge ((36, 29), (36, 30)) is blocked. Removing from graph.
# From (50, 30), observed edge ((38,
# Moving from (45, 29) to (44, 29)
# Moving from (44, 29) to (43, 29)
# Moving from (43, 29) to (43, 30)
# Moving from (43, 30) to (43, 31)
# Moving from (43, 31) to (42, 31)
# Moving from (42, 31) to (42, 32)
# Moving from (42, 32) to (41, 32)
# Moving from (41, 32) to (41, 33)
# Moving from (41, 33) to (41, 34)
# Moving from (41, 34) to (41, 35)
# Moving from (41, 35) to (41, 36)
# Moving from (41, 36) to (41, 37)
# Moving from (41, 37) to (41, 38)
# Moving from (41, 38) to (41, 39)
# Moving from (41, 39) to (41, 40)
# Moving from (41, 40) to (40, 40)
# Moving from (40, 40) to (39, 40)
# Moving from (39, 40) to (38, 40)
# Moving from (38, 40) to (37, 40)
# Moving from (37, 40) to (36, 40)
# Moving from (36, 40) to (36, 41)
# Moving from (36, 41) to (35, 41)
# Moving from (35, 41) to (34, 41)
# From (34, 41), observed edge ((26, 51), (26, 50)) is blocked. Removing from graph.
# From (34, 41), observed edge ((25, 50), (24, 50)) is blocked. Removing from graph.
# From (34, 41), observed edge ((22, 50), (21, 50)) is blocked. Removing from graph.
# From (34, 41), observed edge ((24, 51), (24, 50)) is blocked. Removing from graph.
# From (34, 41), observed edge ((27, 46), (26, 46)) is blocked. Removing from graph.
# From (34, 41), observed edge ((26, 50), (25, 50)) is blocked. Removing from graph.
# From (34, 41), observed edge ((24, 52), (24, 53)) is blocked. Removing from graph.
# From (34, 41), observed edge ((26, 46), (27, 46)) is blocked. Removing from graph.
# From (34, 41), observed edge ((23, 49), (22, 49)) is blocked. Removing from graph.
# From (34, 41), observed edge ((25, 48), (24, 48)) is blocked. Removing from graph.
# From (34, 41), observed edge ((23, 49), (23, 50)) is blocked. Removing from graph.
# From (34, 41), observed edge ((24, 48), (24, 47)) is blocked. Removing from graph.
# From (34, 41), observed edge ((24, 49), (23, 49)) is blocked. Removing from graph.
# From (34, 41), observed edge ((27, 48), (26, 48)) is blocked. Removing from graph.
# From (34, 41), observed edge ((28, 47), (27, 47)) is blocked. Removing from graph.
# From (34, 41), observed edge ((21, 50), (22, 50)) is blocked. Removing from graph.
# From (34, 41), observed edge ((26, 49), (26, 48)) is blocked. Removing from graph.
# From (34, 41), observed edge ((26, 50), (26, 49)) is blocked. Removing from graph.
# From (34, 41), observed edge ((27, 54), (27, 53)) is blocked. Removing from graph.
# From (34, 41), observed edge ((27, 47), (27, 48)) is blocked. Removing from graph.
# From (34, 41), observed edge ((27, 53), (27, 54)) is blocked. Removing from graph.
# From (34, 41), observed edge ((22, 49), (22, 50)) is blocked. Removing from graph.
# From (34, 41), observed edge ((24, 50), (24, 51)) is blocked. Removing from graph.
# From (34, 41), observed edge ((23, 51), (24, 51)) is blocked. Removing from graph.
# From (34, 41), observed edge ((22, 51), (22, 50)) is blocked. Removing from graph.
# From (34, 41), observed edge ((24, 52), (24, 51)) is blocked. Removing from graph.
# From (34, 41), observed edge ((24, 51), (23, 51)) is blocked. Removing from graph.
# From (34, 41), observed edge ((26, 48), (26, 47)) is blocked. Removing from graph.
# From (34, 41), observed edge ((26, 49), (25, 49)) is blocked. Removing from graph.
# From (34, 41), observed edge ((27, 49), (27, 50)) is blocked. Removing from graph.
# From (34, 41), observed edge ((25, 50), (25, 51)) is blocked. Removing from graph.
# From (34, 41), observed edge ((25, 51), (24, 51)) is blocked. Removing from graph.
# From (34, 41), observed edge ((27, 47), (27, 46)) is blocked. Removing from graph.
# From (34, 41), observed edge ((26, 46), (26, 47)) is blocked. Removing from graph.
# From (34, 41), observed edge ((22, 49), (23, 49)) is blocked. Removing from graph.
# From (34, 41), observed edge ((23, 51), (23, 50)) is blocked. Removing from graph.
# From (34, 41), observed edge ((24, 51), (25, 51)) is blocked. Removing from graph.
# From (34, 41), observed edge ((26, 48), (26, 49)) is blocked. Removing from graph.
# From (34, 41), observed edge ((22, 50), (22, 51)) is blocked. Removing from graph.
# From (34, 41), observed edge ((25, 47), (24, 47)) is blocked. Removing from graph.
# From (34, 41), observed edge ((26, 48), (25, 48)) is blocked. Removing from graph.
# From (34, 41), observed edge ((25, 50), (26, 50)) is blocked. Removing from graph.
# From (34, 41), observed edge ((27, 48), (27, 49)) is blocked. Removing from graph.
# From (34, 41), observed edge ((24, 53), (24, 52)) is blocked. Removing from graph.
# From (34, 41), observed edge ((26, 49), (27, 49)) is blocked. Removing from graph.
# From (34, 41), observed edge ((27, 49), (28, 49)) is blocked. Removing from graph.
# From (34, 41), observed edge ((23, 50), (24, 50)) is blocked. Removing from graph.
# From (34, 41), observed edge ((25, 52), (25, 51)) is blocked. Removing from graph.
# From (34, 41), observed edge ((24, 47), (24, 48)) is blocked. Removing from graph.
# From (34, 41), observed edge ((24, 50), (24, 49)) is blocked. Removing from graph.
# From (34, 41), observed edge ((24, 50), (25, 50)) is blocked. Removing from graph.
# From (34, 41), observed edge ((27, 50), (26, 50)) is blocked. Removing from graph.
# From (34, 41), observed edge ((25, 49), (24, 49)) is blocked. Removing from graph.
# From (34, 41), observed edge ((25, 49), (25, 50)) is blocked. Removing from graph.
# From (34, 41), observed edge ((25, 51), (26, 51)) is blocked. Removing from graph.
# From (34, 41), observed edge ((27, 47), (26, 47)) is blocked. Removing from graph.
# From (34, 41), observed edge ((27, 49), (27, 48)) is blocked. Removing from graph.
# From (34, 41), observed edge ((25, 51), (25, 50)) is blocked. Removing from graph.
# From (34, 41), observed edge ((22, 51), (23, 51)) is blocked. Removing from graph.
# From (34, 41), observed edge ((24, 49), (25, 49)) is blocked. Removing from graph.
# From (34, 41), observed edge ((26, 47), (25, 47)) is blocked. Removing from graph.
# From (34, 41), observed edge ((24, 52), (25, 52)) is blocked. Removing from graph.
# From (34, 41), observed edge ((25, 48), (25, 47)) is blocked. Removing from graph.
# From (34, 41), observed edge ((28, 53), (27, 53)) is blocked. Removing from graph.
# From (34, 41), observed edge ((26, 47), (27, 47)) is blocked. Removing from graph.
# From (34, 41), observed edge ((25, 51), (25, 52)) is blocked. Removing from graph.
# From (34, 41), observed edge ((27, 53), (28, 53)) is blocked. Removing from graph.
# From (34, 41), observed edge ((27, 49), (26, 49)) is blocked. Removing from graph.
# From (34, 41), observed edge ((23, 50), (22, 50)) is blocked. Removing from graph.
# From (34, 41), observed edge ((23, 48), (24, 48)) is blocked. Removing from graph.
# From (34, 41), observed edge ((27, 47), (28, 47)) is blocked. Removing from graph.
# From (34, 41), observed edge ((24, 48), (25, 48)) is blocked. Removing from graph.
# From (34, 41), observed edge ((24, 50), (23, 50)) is blocked. Removing from graph.
# From (34, 41), observed edge ((28, 48), (27, 48)) is blocked. Removing from graph.
# From (34, 41), observed edge ((25, 50), (25, 49)) is blocked. Removing from graph.
# From (34, 41), observed edge ((23, 48), (23, 49)) is blocked. Removing from graph.
# From (34, 41), observed edge ((26, 51), (25, 51)) is blocked. Removing from graph.
# From (34, 41), observed edge ((23, 50), (23, 49)) is blocked. Removing from graph.
# From (34, 41), observed edge ((25, 47), (26, 47)) is blocked. Removing from graph.
# From (34, 41), observed edge ((23, 51), (22, 51)) is blocked. Removing from graph.
# From (34, 41), observed edge ((24, 51), (24, 52)) is blocked. Removing from graph.
# From (34, 41), observed edge ((28, 49), (27, 49)) is blocked. Removing from graph.
# From (34, 41), observed edge ((26, 47), (26, 48)) is blocked. Removing from graph.
# From (34, 41), observed edge ((25, 48), (26, 48)) is blocked. Removing from graph.
# From (34, 41), observed edge ((24, 48), (23, 48)) is blocked. Removing from graph.
# From (34, 41), observed edge ((25, 47), (25, 48)) is blocked. Removing from graph.
# From (34, 41), observed edge ((23, 49), (23, 48)) is blocked. Removing from graph.
# From (34, 41), observed edge ((24, 47), (25, 47)) is blocked. Removing from graph.
# From (34, 41), observed edge ((25, 52), (24, 52)) is blocked. Removing from graph.
# From (34, 41), observed edge ((25, 49), (26, 49)) is blocked. Removing from graph.
# From (34, 41), observed edge ((24, 49), (24, 48)) is blocked. Removing from graph.
# From (34, 41), observed edge ((27, 46), (27, 47)) is blocked. Removing from graph.
# From (34, 41), observed edge ((27, 50), (27, 49)) is blocked. Removing from graph.
# From (34, 41), observed edge ((25, 49), (25, 48)) is blocked. Removing from graph.
# From (34, 41), observed edge ((26, 50), (26, 51)) is blocked. Removing from graph.
# From (34, 41), observed edge ((23, 50), (23, 51)) is blocked. Removing from graph.
# ...
# From (17, 15), observed edge ((14, 13), (14, 14)) is blocked. Removing from graph.
# Moving from (17, 15) to (18, 15)
# From (18, 15), observed edge ((10, 12), (10, 11)) is blocked. Removing from graph.
# From (18, 15), observed edge ((17, 13), (16, 13)) is blocked. Removing from graph.
# From (18, 15), observed edge ((15, 14), (15, 15)) is blocked. Removing from graph.
# From (18, 15), observed edge ((10, 12), (11, 12)) is blocked. Removing from graph.
# From (18, 15), observed edge ((16, 11), (15, 11)) is blocked. Removing from graph.
# From (18, 15), observed edge ((16, 11), (16, 12)) is blocked. Removing from graph.
# From (18, 15), observed edge ((11, 12), (10, 12)) is blocked. Removing from graph.
# From (18, 15), observed edge ((16, 12), (15, 12)) is blocked. Removing from graph.
# From (18, 15), observed edge ((12, 13), (12, 12)) is blocked. Removing from graph.
# From (18, 15), observed edge ((17, 12), (16, 12)) is blocked. Removing from graph.
# From (18, 15), observed edge ((16, 13), (17, 13)) is blocked. Removing from graph.
# From (18, 15), observed edge ((16, 12), (16, 13)) is blocked. Removing from graph.
# From (18, 15), observed edge ((15, 10), (15, 11)) is blocked. Removing from graph.
# From (18, 15), observed edge ((12, 12), (12, 13)) is blocked. Removing from graph.
# From (18, 15), observed edge ((13, 13), (12, 13)) is blocked. Removing from graph.
# From (18, 15), observed edge ((15, 11), (16, 11)) is blocked. Removing from graph.
# From (18, 15), observed edge ((16, 13), (16, 12)) is blocked. Removing from graph.
# From (18, 15), observed edge ((14, 14), (14, 15)) is blocked. Removing from graph.
# From (18, 15), observed edge ((16, 12), (17, 12)) is blocked. Removing from graph.
# From (18, 15), observed edge ((14, 15), (14, 14)) is blocked. Removing from graph.
# From (18, 15), observed edge ((15, 11), (15, 10)) is blocked. Removing from graph.
# From (18, 15), observed edge ((16, 12), (16, 11)) is blocked. Removing from graph.
# From (18, 15), observed edge ((10, 11), (10, 12)) is blocked. Removing from graph.
# From (18, 15), observed edge ((15, 15), (15, 14)) is blocked. Removing from graph.
# From (18, 15), observed edge ((15, 12), (16, 12)) is blocked. Removing from graph.
# From (18, 15), observed edge ((12, 13), (13, 13)) is blocked. Removing from graph.
# Moving from (18, 15) to (18, 14)
# Moving from (18, 14) to (19, 14)
# Moving from (19, 14) to (20, 14)
# Moving from (20, 14) to (21, 14)
# Moving from (21, 14) to (22, 14)
# From (22, 14), observed edge ((36, 27), (36, 26)) is blocked. Removing from graph.
# From (22, 14), observed edge ((36, 26), (36, 27)) is blocked. Removing from graph.
# Moving from (22, 14) to (23, 14)
# Moving from (23, 14) to (23, 13)
# From (23, 13), observed edge ((10, 12), (9, 12)) is blocked. Removing from graph.
# From (23, 13), observed edge ((10, 13), (10, 12)) is blocked. Removing from graph.
# From (23, 13), observed edge ((10, 13), (11, 13)) is blocked. Removing from graph.
# From (23, 13), observed edge ((9, 12), (10, 12)) is blocked. Removing from graph.
# From (23, 13), observed edge ((12, 13), (11, 13)) is blocked. Removing from graph.
# From (23, 13), observed edge ((11, 13), (11, 12)) is blocked. Removing from graph.
# From (23, 13), observed edge ((10, 12), (10, 13)) is blocked. Removing from graph.
# From (23, 13), observed edge ((11, 13), (10, 13)) is blocked. Removing from graph.
# From (23, 13), observed edge ((11, 12), (11, 13)) is blocked. Removing from graph.
# From (23, 13), observed edge ((11, 13), (12, 13)) is blocked. Removing from graph.
# Moving from (23, 13) to (23, 12)
# From (23, 12), observed edge ((13, 14), (14, 14)) is blocked. Removing from graph.
# From (23, 12), observed edge ((11, 14), (12, 14)) is blocked. Removing from graph.
# From (23, 12), observed edge ((13, 14), (12, 14)) is blocked. Removing from graph.
# From (23, 12), observed edge ((14, 14), (13, 14)) is blocked. Removing from graph.
# From (23, 12), observed edge ((12, 14), (12, 13)) is blocked. Removing from graph.
# From (23, 12), observed edge ((11, 13), (11, 14)) is blocked. Removing from graph.
# From (23, 12), observed edge ((13, 14), (13, 13)) is blocked. Removing from graph.
# From (23, 12), observed edge ((12, 14), (13, 14)) is blocked. Removing from graph.
# From (23, 12), observed edge ((13, 13), (13, 14)) is blocked. Removing from graph.
# From (23, 12), observed edge ((12, 14), (11, 14)) is blocked. Removing from graph.
# From (23, 12), observed edge ((12, 13), (12, 14)) is blocked. Removing from graph.
# From (23, 12), observed edge ((11, 14), (11, 13)) is blocked. Removing from graph.
# Moving from (23, 12) to (23, 11)
# Moving from (23, 11) to (24, 11)
# Moving from (24, 11) to (25, 11)
# Moving from (25, 11) to (26, 11)
# Moving from (26, 11) to (26, 10)
# Moving from (26, 10) to (27, 10)
# From (27, 10), observed edge ((12, 15), (12, 14)) is blocked. Removing from graph.
# From (27, 10), observed edge ((12, 14), (12, 15)) is blocked. Removing from graph.
# From (27, 10), observed edge ((13, 16), (13, 15)) is blocked. Removing from graph.
# From (27, 10), observed edge ((13, 15), (12, 15)) is blocked. Removing from graph.
# From (27, 10), observed edge ((12, 15), (13, 15)) is blocked. Removing from graph.
# From (27, 10), observed edge ((13, 14), (13, 15)) is blocked. Removing from graph.
# From (27, 10), observed edge ((13, 15), (13, 16)) is blocked. Removing from graph.
# From (27, 10), observed edge ((13, 15), (13, 14)) is blocked. Removing from graph.
# Moving from (27, 10) to (28, 10)
# From (28, 10), observed edge ((10, 13), (10, 14)) is blocked. Removing from graph.
# From (28, 10), observed edge ((11, 15), (11, 14)) is blocked. Removing from graph.
# From (28, 10), observed edge ((11, 14), (11, 15)) is blocked. Removing from graph.
# From (28, 10), observed edge ((10, 13), (9, 13)) is blocked. Removing from graph.
# From (28, 10), observed edge ((10, 15), (10, 14)) is blocked. Removing from graph.
# From (28, 10), observed edge ((10, 14), (11, 14)) is blocked. Removing from graph.
# From (28, 10), observed edge ((10, 14), (10, 13)) is blocked. Removing from graph.
# From (28, 10), observed edge ((10, 14), (10, 15)) is blocked. Removing from graph.
# From (28, 10), observed edge ((9, 13), (10, 13)) is blocked. Removing from graph.
# From (28, 10), observed edge ((11, 14), (10, 14)) is blocked. Removing from graph.
# Moving from (28, 10) to (28, 9)
# Moving from (28, 9) to (29, 9)
# From (29, 9), observed edge ((10, 14), (9, 14)) is blocked. Removing from graph.
# From (29, 9), observed edge ((9, 14), (10, 14)) is blocked. Removing from graph.
# Moving from (29, 9) to (30, 9)
# Moving from (30, 9) to (31, 9)
# Moving from (31, 9) to (32, 9)
# Moving from (32, 9) to (33, 9)
# Moving from (33, 9) to (33, 10)
# Moving from (33, 10) to (33, 11)
# Moving from (33, 11) to (33, 12)
# Moving from (33, 12) to (33, 13)
# Moving from (33, 13) to (33, 14)
# Moving from (33, 14) to (33, 15)
# Moving from (33, 15) to (33, 16)
# Moving from (33, 16) to (33, 17)
# Moving from (33, 17) to (33, 16)
# Moving from (33, 16) to (33, 15)
# Moving from (33, 15) to (33, 14)
# Moving from (33, 14) to (33, 13)
# Moving from (33, 13) to (33, 12)
# Moving from (33, 12) to (33, 11)
# Moving from (33, 11) to (33, 10)
# Moving from (33, 10) to (33, 9)
# Moving from (33, 9) to (32, 9)
# Moving from (32, 9) to (31, 9)
# Moving from (31, 9) to (30, 9)
# Moving from (30, 9) to (29, 9)
# Moving from (29, 9) to (28, 9)
# Moving from (28, 9) to (28, 10)
# Moving from (28, 10) to (27, 10)
# Moving from (27, 10) to (26, 10)
# Moving from (26, 10) to (26, 11)
# Moving from (26, 11) to (25, 11)
# Moving from (25, 11) to (24, 11)
# Moving from (24, 11) to (23, 11)
# Moving from (23, 11) to (23, 12)
# Moving from (23, 12) to (23, 13)
# Moving from (23, 13) to (23, 14)
# Moving from (23, 14) to (22, 14)
# Moving from (22, 14) to (21, 14)
# Moving from (21, 14) to (20, 14)
# Moving from (20, 14) to (19, 14)
# Moving from (19, 14) to (18, 14)
# Moving from (18, 14) to (18, 15)
# Moving from (18, 15) to (18, 16)
# Moving from (18, 16) to (18, 17)
# Moving from (18, 17) to (18, 18)
# Moving from (43, 10) to (43, 9)
# Moving from (43, 9) to (42, 9)
# Moving from (42, 9) to (41, 9)
# Moving from (41, 9) to (40, 9)
# Moving from (40, 9) to (40, 8)
# Moving from (40, 8) to (40, 7)
# Moving from (40, 7) to (39, 7)
# Moving from (39, 7) to (39, 6)
# Moving from (39, 6) to (38, 6)
# From (38, 6), observed edge ((13, 15), (14, 15)) is blocked. Removing from graph.
# From (38, 6), observed edge ((14, 15), (13, 15)) is blocked. Removing from graph.
# Moving from (38, 6) to (38, 5)
# Moving from (38, 5) to (37, 5)
# Moving from (37, 5) to (37, 6)
# Moving from (37, 6) to (37, 7)
# Moving from (37, 7) to (37, 8)
# Moving from (37, 8) to (37, 9)
# Moving from (37, 9) to (36, 9)
# Moving from (36, 9) to (35, 9)
# Moving from (35, 9) to (34, 9)
# Moving from (34, 9) to (33, 9)
# Moving from (33, 9) to (32, 9)
# Moving from (32, 9) to (31, 9)
# Moving from (31, 9) to (30, 9)
# Moving from (30, 9) to (29, 9)
# Moving from (29, 9) to (28, 9)
# Moving from (28, 9) to (28, 10)
# Moving from (28, 10) to (27, 10)
# Moving from (27, 10) to (26, 10)
# Moving from (26, 10) to (26, 11)
# Moving from (26, 11) to (25, 11)
# Moving from (25, 11) to (24, 11)
# Moving from (24, 11) to (23, 11)
# Moving from (23, 11) to (23, 12)
# Moving from (23, 12) to (23, 13)
# Moving from (23, 13) to (23, 14)
# Moving from (23, 14) to (22, 14)
# Moving from (22, 14) to (22, 15)
# Moving from (22, 15) to (22, 16)
# Moving from (22, 16) to (22, 17)
# Moving from (22, 17) to (22, 18)
# Moving from (22, 18) to (22, 19)
# Moving from (22, 19) to (23, 19)
# Moving from (23, 19) to (23, 20)
# Moving from (23, 20) to (24, 20)
# Moving from (24, 20) to (25, 20)
# Moving from (25, 20) to (25, 21)
# Moving from (25, 21) to (26, 21)
# Moving from (26, 21) to (27, 21)
# Moving from (27, 21) to (27, 22)
# Moving from (27, 22) to (27, 23)
# Moving from (27, 23) to (27, 24)
# Moving from (27, 24) to (27, 25)
# Moving from (27, 25) to (27, 26)
# Moving from (27, 26) to (27, 27)
# Moving from (27, 27) to (27, 28)
# From (27, 28), observed edge ((26, 55), (25, 55)) is blocked. Removing from graph.
# From (27, 28), observed edge ((25, 55), (26, 55)) is blocked. Removing from graph.
# Moving from (27, 28) to (26, 28)
# Moving from (26, 28) to (26, 29)
# Moving from (26, 29) to (25, 29)
# Moving from (25, 29) to (25, 30)
# Moving from (25, 30) to (25, 31)
# Moving from (25, 31) to (25, 32)
# Moving from (25, 32) to (25, 33)
# Moving from (25, 33) to (25, 34)
# Moving from (25, 34) to (26, 34)
# Moving from (26, 34) to (26, 35)
# Moving from (26, 35) to (27, 35)
# Moving from (27, 35) to (28, 35)
# Moving from (28, 35) to (29, 35)
# Moving from (29, 35) to (30, 35)
# Moving from (30, 35) to (31, 35)
# Moving from (31, 35) to (32, 35)
# Moving from (32, 35) to (33, 35)
# Moving from (33, 35) to (34, 35)

# %%
# --- Grid spacing (64x64 grid) ---
xs = sorted(set(p[0] for p in pos.values()))
ys = sorted(set(p[1] for p in pos.values()))
cell_w = xs[1] - xs[0]
cell_h = ys[1] - ys[0]

fig, ax = plt.subplots(figsize=(10, 10))

# --- Terrain squares (obstacles black; everything else height-coloured) ---
for node, data in blocked_env_graph.nodes(data=True):
    x, y = pos[node]
    if data.get("type") == "obstacle":
        color = "black"
    else:
        color = cmap(norm(data.get('height', 0)))
    ax.add_patch(patches.Rectangle(
        (x - cell_w / 2, y - cell_h / 2), cell_w, cell_h,
        linewidth=0, facecolor=color
    ))

# Colorbar
sm = plt.cm.ScalarMappable(cmap=cmap, norm=norm)
sm.set_array([])
cbar = fig.colorbar(sm, ax=ax, fraction=0.046, pad=0.04)
cbar.set_label('Height Value', rotation=270, labelpad=15, fontsize=12)

# --- Path edges ---
path_1_edges = {tuple(sorted((path_1[i], path_1[i+1])))
                for i in range(len(path_1) - 1)}
path1_original_edges = {tuple(sorted((path_1_original[i], path_1_original[i+1])))
                for i in range(len(path_1_original) - 1)}

line_segments = [[pos[u], pos[v]] for u, v in path_1_edges]
dashed_line_segments = [[pos[u], pos[v]] for u, v in path1_original_edges]

ax.add_collection(mc.LineCollection(line_segments, colors='red', linewidths=5.0, zorder=3))
ax.add_collection(mc.LineCollection(dashed_line_segments, colors='green', linewidth=2.5,
                                    zorder=5, linestyles='dashed'))

# --- Source / target markers (reads agent's view env_graph1 so reached targets show grey) ---
src_pts, unreached_pts, reached_pts = [], [], []
for node, data in env_graph1.nodes(data=True):
    t = data.get("type")
    if t == "source":
        src_pts.append(pos[node])
    elif t == "target_unreached":
        unreached_pts.append(pos[node])
    elif t == "target_reached":
        reached_pts.append(pos[node])

if src_pts:
    ax.scatter([p[0] for p in src_pts], [p[1] for p in src_pts],
               marker='o', s=220, facecolor='limegreen', edgecolor='darkgreen',
               linewidths=1.5, zorder=10)
if unreached_pts:
    ax.scatter([p[0] for p in unreached_pts], [p[1] for p in unreached_pts],
               marker='x', s=200, color='red', linewidths=3, zorder=10)
if reached_pts:
    ax.scatter([p[0] for p in reached_pts], [p[1] for p in reached_pts],
               marker='x', s=200, color='grey', linewidths=3, zorder=10)

# --- Fit axes tightly to the grid ---
ax.set_xlim(xs[0] - cell_w / 2, xs[-1] + cell_w / 2)
ax.set_ylim(ys[0] - cell_h / 2, ys[-1] + cell_h / 2)
ax.set_aspect('equal')
ax.axis('off')

plt.tight_layout()
plt.show()

# --- Path length ---
total_path_length = 0.0
for i in range(len(path_1) - 1):
    u = path_1[i]
    v = path_1[i + 1]
    edge_data = blocked_env_graph.get_edge_data(u, v)
    if edge_data:
        total_path_length += edge_data.get('distance', 0.0)
print(f"Total path length taken by the agent: {total_path_length:.2f}")
# Out:
# Total path length taken by the agent: 491.90

# %% [markdown]
# Let's now see what our agent intends to do

# %%
from Single_Agent.repeated_topk import RepeatedTopK

env_graph2 = env_graph.copy()
source = (N-1, N-1)
path2_generator = RepeatedTopK(
    reward_ratio=3.0, env_graph=env_graph2,
    sample_recursion=3, sample_num_obstacle=3, sample_obstacle_hop=4,
    target_graph_num_neighbors=4, target_graph_recursions=3, target_graph_obstacle_hop=3, target_graph_num_obstacles=3
)
path_2 = path2_generator.find_best_path(source)
path_2_original = path_2.copy()

current_node = path_2[0]
index = 0

while index < len(path_2) - 1:
    next_node = path_2[index + 1]

    # Mark target as reached when we arrive at it
    if env_graph2.nodes[current_node].get('type') == 'target_unreached':
        env_graph2.nodes[current_node]['type'] = 'target_reached'

    # Check out all the observable edges
    observable_edges = set(blocked_env_graph.nodes[current_node]["visible_edges"])
    assumed_observable_edges = set(env_graph2.nodes[current_node]["visible_edges"])
    blocked_edges = assumed_observable_edges - observable_edges

    # MARK OBSERVED EDGES AS SEEN
    for edge in assumed_observable_edges:
        if env_graph2.has_edge(*edge):
            env_graph2.edges[edge]["observed_edge"] = True

    if len(blocked_edges) > 0:
        # Remove blocked edges from agent's world model
        for edge in blocked_edges:
            u, v = edge
            if env_graph2.has_edge(u, v):
                print(f"From {current_node}, observed edge ({u}, {v}) is blocked. Removing from graph.")
                env_graph2.remove_edge(u, v)

        # Update the visibility mapping as well
        for node in env_graph2.nodes():
            if "visible_edges" in env_graph2.nodes[node]:
                current_visible = env_graph2.nodes[node]["visible_edges"]
                updated_visible = set(current_visible) - blocked_edges
                env_graph2.nodes[node]["visible_edges"] = list(updated_visible)

        # Check if any blocked edge is in our current path
        path_edges = [(path_2[i], path_2[i+1]) for i in range(index, len(path_2) - 1)]
        blocked_edges_both_directions = set()
        for u, v in blocked_edges:
            blocked_edges_both_directions.add((u, v))
            blocked_edges_both_directions.add((v, u))

        if any(edge in blocked_edges_both_directions for edge in path_edges):
            print(f"Blocked edge detected in planned path. Recalculating from {current_node}...")
            path_2 = path_2[:index + 1] + path2_generator.find_best_path(current_node)[1:]

    # Move to the next node
    next_node = path_2[index + 1]
    print(f"Moving from {current_node} to {next_node}")
    current_node = next_node
    index += 1

# Mark the final node if it's a target
if env_graph2.nodes[current_node].get('type') == 'target_unreached':
    env_graph2.nodes[current_node]['type'] = 'target_reached'
# Out:
# Moving from (63, 63) to (62, 63)
# Moving from (62, 63) to (61, 63)
# Moving from (61, 63) to (60, 63)
# Moving from (60, 63) to (59, 63)
# Moving from (59, 63) to (58, 63)
# Moving from (58, 63) to (58, 62)
# Moving from (58, 62) to (57, 62)
# Moving from (57, 62) to (56, 62)
# Moving from (56, 62) to (55, 62)
# Moving from (55, 62) to (54, 62)
# Moving from (54, 62) to (53, 62)
# Moving from (53, 62) to (52, 62)
# Moving from (52, 62) to (51, 62)
# Moving from (51, 62) to (50, 62)
# Moving from (50, 62) to (49, 62)
# Moving from (49, 62) to (49, 63)
# Moving from (49, 63) to (48, 63)
# Moving from (48, 63) to (47, 63)
# Moving from (47, 63) to (46, 63)
# Moving from (46, 63) to (45, 63)
# Moving from (45, 63) to (44, 63)
# Moving from (44, 63) to (43, 63)
# Moving from (43, 63) to (42, 63)
# Moving from (42, 63) to (41, 63)
# Moving from (41, 63) to (40, 63)
# Moving from (40, 63) to (39, 63)
# Moving from (39, 63) to (38, 63)
# Moving from (38, 63) to (37, 63)
# Moving from (37, 63) to (37, 62)
# Moving from (37, 62) to (37, 61)
# Moving from (37, 61) to (37, 60)
 50)) is blocked. Removing from graph.
# From (32, 41), observed edge ((23, 48), (24, 48)) is blocked. Removing from graph.
# From (32, 41), observed edge ((19, 44), (19, 45)) is blocked. Removing from graph.
# From (32, 41), observed edge ((19, 48), (19, 47)) is blocked. Removing from graph.
# From (32, 41), observed edge ((24, 48), (25, 48)) is blocked. Removing from graph.
# From (32, 41), observed edge ((15, 44), (14, 44)) is blocked. Removing from graph.
# From (32, 41), observed edge ((28, 48), (27, 48)) is blocked. Removing from graph.
# From (32, 41), observed edge ((22, 47), (23, 47)) is blocked. Removing from graph.
# From (32, 41), observed edge ((18, 40), (17, 40)) is blocked. Removing from graph.
# From (32, 41), observed edge ((20, 46), (21, 46)) is blocked. Removing from graph.
# From (32, 41), observed edge ((25, 47), (26, 47)) is blocked. Removing from graph.
# From (32, 41), observed edge ((28, 51), (27, 51)) is blocked. Removing from graph.
# From (32, 41), observed edge ((26, 53), (26, 52)) is blocked. Removing from graph.
# From (32, 41), observed edge ((19, 46), (18, 46)) is blocked. Removing from graph.
# From (32, 41), observed edge ((23, 47), (24, 47)) is blocked. Removing from graph.
# From (32, 41), observed edge ((21, 46), (21, 47)) is blocked. Removing from graph.
# From (32, 41), observed edge ((17, 42), (17, 41)) is blocked. Removing from graph.
# From (32, 41), observed edge ((27, 53), (26, 53)) is blocked. Removing from graph.
# From (32, 41), observed edge ((27, 51), (28, 51)) is blocked. Removing from graph.
# From (32, 41), observed edge ((21, 45), (21, 44)) is blocked. Removing from graph.
# From (32, 41), observed edge ((25, 48), (26, 48)) is blocked. Removing from graph.
# From (32, 41), observed edge ((25, 47), (25, 48)) is blocked. Removing from graph.
# From (32, 41), observed edge ((19, 45), (20, 45)) is blocked. Removing from graph.
# From (32, 41), observed edge ((20, 42), (20, 43)) is blocked. Removing from graph.
# From (32, 41), observed edge ((26, 53), (25, 53)) is blocked. Removing from graph.
# From (32, 41), observed edge ((18, 47), (17, 47)) is blocked. Removing from graph.
# From (32, 41), observed edge ((58, 37), (58, 38)) is blocked. Removing from graph.
# From (32, 41), observed edge ((26, 54), (27, 54)) is blocked. Removing from graph.
# From (32, 41), observed edge ((19, 47), (19, 48)) is blocked. Removing from graph.
# From (32, 41), observed edge ((23, 50), (23, 51)) is blocked. Removing from graph.
# From (32, 41), observed edge ((25, 48), (25, 49)) is blocked. Removing from graph.
# From (32, 41), observed edge ((20, 43), (20, 42)) is blocked. Removing from graph.
# From (32, 41), observed edge ((17, 41), (18, 41)) is blocked. Removing from graph.
# From (32, 41), observed edge ((18, 43), (17, 43)) is blocked. Removing from graph.
# From (32, 41), observed edge ((19, 42), (18, 42)) is blocked. Removing from graph.
# From (32, 41), observed edge ((15, 46), (15, 47)) is blocked. Removing from graph.
# From (32, 41), observed edge ((26, 50), (27, 50)) is blocked. Removing from graph.
# From (32, 41), observed edge ((16, 41), (16, 40)) is blocked. Removing from graph.
# From (32, 41), observed edge ((15, 41), (16, 41)) is blocked. Removing from graph.
# From (32, 41), observed edge ((19, 40), (19, 41)) is blocked. Removing from graph.
# From (32, 41), observed edge ((24, 48), (24, 49)) is blocked. Removing from graph.
# From (32, 41), observed edge ((22, 50), (23, 50)) is blocked. Removing from graph.
# From (32, 41), observed edge ((25, 47), (25, 46)) is blocked. Removing from graph.
# From (32, 41), observed edge ((21, 46), (20, 46)) is blocked. Removing from graph.
# From (32, 41), observed edge ((26, 49), (26, 50)) is blocked. Removing from graph.
# From (32, 41), observed edge ((16, 45), (17, 45)) is blocked. Removing from graph.
# From (32, 41), observed edge ((27, 48), (27, 47)) is blocked. Removing from graph.
# From (32, 41), observed edge ((20, 46), (20, 47)) is blocked. Removing from graph.
# From (32, 41), observed edge ((16, 42), (17, 42)) is blocked. Removing from graph.
# From (32, 41), observed edge ((19, 47), (19, 46)) is blocked. Removing from graph.
# From (32, 41), observed edge ((16, 46), (17, 46)) is blocked. Removing from graph.
# From (32, 41), observed edge ((24, 51), (24, 50)) is blocked. Removing from graph.
# From (32, 41), observed edge ((22, 43), (22, 44)) is blocked. Removing from graph.
# From (32, 41), observed edge ((14, 43), (14, 44)) is blocked. Removing from graph.
# From (32, 41), observed edge ((18, 46), (18, 47)) is blocked. Removing from graph.
# From (32, 41), observed edge ((27, 46), (26, 46)) is blocked. Removing from graph.
# From (32, 41), observed edge ((27, 51), (27, 52)) is blocked. Removing from graph.
# From (32, 41), observed edge ((21, 45), (20, 45)) is blocked. Removing from graph.
# From (32, 41), observed edge ((20, 45), (20, 44)) is blocked. Removing from graph.
# From (32, 41), observed edge ((23, 49), (23, 50)) is blocked. Removing from graph.
# From (32, 41), observed edge ((24, 48), (24, 47)) is blocked. Removing from graph.
# From (32, 41), observed edge ((20, 44), (19, 44)) is blocked. Removing from graph.
# From (32, 41), observed edge ((16, 48), (16, 47)) is blocked. Removing from graph.
# From (32, 41), observed edge ((17, 45), (16, 45)) is blocked. Removing from graph.
# From (32, 41), observed edge ((28, 47), (27, 47)) is blocked. Removing from graph.
# From (32, 41), observed edge ((26, 49), (26, 48)) is blocked. Removing from graph.
# From (32, 41), observed edge ((27, 54), (27, 53)) is blocked. Removing from graph.
# ...
# From (25, 30), observed edge ((15, 17), (16, 17)) is blocked. Removing from graph.
# From (25, 30), observed edge ((12, 18), (12, 17)) is blocked. Removing from graph.
# From (25, 30), observed edge ((11, 15), (11, 14)) is blocked. Removing from graph.
# From (25, 30), observed edge ((13, 17), (13, 16)) is blocked. Removing from graph.
# From (25, 30), observed edge ((14, 18), (13, 18)) is blocked. Removing from graph.
# From (25, 30), observed edge ((14, 17), (13, 17)) is blocked. Removing from graph.
# From (25, 30), observed edge ((14, 17), (14, 18)) is blocked. Removing from graph.
# From (25, 30), observed edge ((13, 11), (13, 12)) is blocked. Removing from graph.
# From (25, 30), observed edge ((12, 10), (12, 11)) is blocked. Removing from graph.
# From (25, 30), observed edge ((9, 15), (9, 14)) is blocked. Removing from graph.
# From (25, 30), observed edge ((13, 13), (13, 12)) is blocked. Removing from graph.
# From (25, 30), observed edge ((12, 15), (12, 16)) is blocked. Removing from graph.
# From (25, 30), observed edge ((13, 12), (13, 13)) is blocked. Removing from graph.
# From (25, 30), observed edge ((14, 13), (13, 13)) is blocked. Removing from graph.
# From (25, 30), observed edge ((12, 17), (12, 16)) is blocked. Removing from graph.
# From (25, 30), observed edge ((13, 10), (13, 11)) is blocked. Removing from graph.
# From (25, 30), observed edge ((15, 17), (14, 17)) is blocked. Removing from graph.
# Moving from (25, 30) to (25, 29)
# From (25, 29), observed edge ((10, 17), (11, 17)) is blocked. Removing from graph.
# From (25, 29), observed edge ((11, 18), (11, 17)) is blocked. Removing from graph.
# From (25, 29), observed edge ((14, 11), (14, 12)) is blocked. Removing from graph.
# From (25, 29), observed edge ((17, 16), (16, 16)) is blocked. Removing from graph.
# From (25, 29), observed edge ((9, 13), (9, 14)) is blocked. Removing from graph.
# From (25, 29), observed edge ((11, 17), (11, 18)) is blocked. Removing from graph.
# From (25, 29), observed edge ((13, 11), (14, 11)) is blocked. Removing from graph.
# From (25, 29), observed edge ((14, 12), (14, 11)) is blocked. Removing from graph.
# From (25, 29), observed edge ((10, 13), (10, 14)) is blocked. Removing from graph.
# From (25, 29), observed edge ((10, 17), (10, 16)) is blocked. Removing from graph.
# From (25, 29), observed edge ((10, 16), (10, 17)) is blocked. Removing from graph.
# From (25, 29), observed edge ((11, 17), (10, 17)) is blocked. Removing from graph.
# From (25, 29), observed edge ((16, 16), (17, 16)) is blocked. Removing from graph.
# From (25, 29), observed edge ((10, 13), (9, 13)) is blocked. Removing from graph.
# From (25, 29), observed edge ((10, 16), (9, 16)) is blocked. Removing from graph.
# From (25, 29), observed edge ((16, 15), (16, 14)) is blocked. Removing from graph.
# From (25, 29), observed edge ((10, 14), (10, 13)) is blocked. Removing from graph.
# From (25, 29), observed edge ((9, 14), (9, 13)) is blocked. Removing from graph.
# From (25, 29), observed edge ((16, 14), (16, 15)) is blocked. Removing from graph.
# From (25, 29), observed edge ((15, 14), (16, 14)) is blocked. Removing from graph.
# From (25, 29), observed edge ((14, 13), (15, 13)) is blocked. Removing from graph.
# From (25, 29), observed edge ((16, 14), (15, 14)) is blocked. Removing from graph.
# From (25, 29), observed edge ((9, 13), (10, 13)) is blocked. Removing from graph.
# From (25, 29), observed edge ((15, 13), (15, 14)) is blocked. Removing from graph.
# From (25, 29), observed edge ((13, 10), (13, 9)) is blocked. Removing from graph.
# From (25, 29), observed edge ((13, 9), (13, 10)) is blocked. Removing from graph.
# From (25, 29), observed edge ((9, 16), (10, 16)) is blocked. Removing from graph.
# From (25, 29), observed edge ((15, 14), (15, 13)) is blocked. Removing from graph.
# From (25, 29), observed edge ((15, 13), (14, 13)) is blocked. Removing from graph.
# From (25, 29), observed edge ((14, 11), (13, 11)) is blocked. Removing from graph.
# Moving from (25, 29) to (26, 29)
# From (26, 29), observed edge ((25, 55), (24, 55)) is blocked. Removing from graph.
# From (26, 29), observed edge ((24, 55), (25, 55)) is blocked. Removing from graph.
# Moving from (26, 29) to (26, 28)
# From (26, 28), observed edge ((10, 13), (10, 12)) is blocked. Removing from graph.
# From (26, 28), observed edge ((12, 14), (12, 13)) is blocked. Removing from graph.
# From (26, 28), observed edge ((11, 13), (11, 12)) is blocked. Removing from graph.
# From (26, 28), observed edge ((10, 12), (10, 11)) is blocked. Removing from graph.
# From (26, 28), observed edge ((10, 12), (11, 12)) is blocked. Removing from graph.
# From (26, 28), observed edge ((11, 12), (11, 13)) is blocked. Removing from graph.
# From (26, 28), observed edge ((14, 15), (13, 15)) is blocked. Removing from graph.
# From (26, 28), observed edge ((13, 15), (14, 15)) is blocked. Removing from graph.
# From (26, 28), observed edge ((9, 12), (10, 12)) is blocked. Removing from graph.
# From (26, 28), observed edge ((12, 15), (12, 14)) is blocked. Removing from graph.
# From (26, 28), observed edge ((14, 15), (14, 16)) is blocked. Removing from graph.
# From (26, 28), observed edge ((12, 14), (12, 15)) is blocked. Removing from graph.
# From (26, 28), observed edge ((11, 13), (11, 14)) is blocked. Removing from graph.
# From (26, 28), observed edge ((11, 12), (10, 12)) is blocked. Removing from graph.
# From (26, 28), observed edge ((12, 14), (11, 14)) is blocked. Removing from graph.
# From (26, 28), observed edge ((13, 15), (13, 14)) is blocked. Removing from graph.
# From (26, 28), observed edge ((11, 14), (12, 14)) is blocked. Removing from graph.
# From (26, 28), observed edge ((10, 12), (10, 13)) is blocked. Removing from graph.
# From (26, 28), observed edge ((11, 13), (10, 13)) is blocked. Removing from graph.
# From (26, 28), observed edge ((13, 14), (13, 15)) is blocked. Removing from graph.
# From (26, 28), observed edge ((12, 13), (12, 14)) is blocked. Removing from graph.
# From (26, 28), observed edge ((14, 16), (14, 15)) is blocked. Removing from graph.
# From (26, 28), observed edge ((11, 14), (11, 13)) is blocked. Removing from graph.
# From (26, 28), observed edge ((10, 12), (9, 12)) is blocked. Removing from graph.
# From (26, 28), observed edge ((10, 13), (11, 13)) is blocked. Removing from graph.
# From (26, 28), observed edge ((13, 14), (12, 14)) is blocked. Removing from graph.
# From (26, 28), observed edge ((12, 13), (11, 13)) is blocked. Removing from graph.
# From (26, 28), observed edge ((12, 14), (13, 14)) is blocked. Removing from graph.
# From (26, 28), observed edge ((10, 11), (10, 12)) is blocked. Removing from graph.
# From (26, 28), observed edge ((11, 13), (12, 13)) is blocked. Removing from graph.
# Moving from (26, 28) to (27, 28)
# Moving from (27, 28) to (27, 27)
# Moving from (27, 27) to (27, 26)
# Moving from (27, 26) to (27, 25)
# From (27, 25), observed edge ((16, 14), (17, 14)) is blocked. Removing from graph.
# From (27, 25), observed edge ((15, 11), (15, 12)) is blocked. Removing from graph.
# From (27, 25), observed edge ((16, 13), (15, 13)) is blocked. Removing from graph.
# From (27, 25), observed edge ((14, 12), (15, 12)) is blocked. Removing from graph.
# From (27, 25), observed edge ((13, 14), (13, 13)) is blocked. Removing from graph.
# From (27, 25), observed edge ((17, 13), (16, 13)) is blocked. Removing from graph.
# From (27, 25), observed edge ((14, 10), (14, 11)) is blocked. Removing from graph.
# From (27, 25), observed edge ((17, 15), (16, 15)) is blocked. Removing from graph.
# From (27, 25), observed edge ((17, 14), (18, 14)) is blocked. Removing from graph.
# From (27, 25), observed edge ((15, 13), (15, 12)) is blocked. Removing from graph.
# From (27, 25), observed edge ((13, 14), (14, 14)) is blocked. Removing from graph.
# From (27, 25), observed edge ((16, 14), (16, 13)) is blocked. Removing from graph.
# From (27, 25), observed edge ((15, 11), (14, 11)) is blocked. Removing from graph.
# From (27, 25), observed edge ((15, 13), (16, 13)) is blocked. Removing from graph.
# From (27, 25), observed edge ((16, 15), (17, 15)) is blocked. Removing from graph.
# From (27, 25), observed edge ((13, 12), (12, 12)) is blocked. Removing from graph.
# From (27, 25), observed edge ((14, 11), (15, 11)) is blocked. Removing from graph.
# From (27, 25), observed edge ((14, 10), (13, 10)) is blocked. Removing from graph.
# From (27, 25), observed edge ((16, 12), (15, 12)) is blocked. Removing from graph.
# From (27, 25), observed edge ((17, 14), (17, 13)) is blocked. Removing from graph.
# From (27, 25), observed edge ((13, 13), (13, 14)) is blocked. Removing from graph.
# From (27, 25), observed edge ((12, 13), (12, 12)) is blocked. Removing from graph.
# From (27, 25), observed edge ((10, 11), (11, 11)) is blocked. Removing from graph.
# From (27, 25), observed edge ((16, 13), (17, 13)) is blocked. Removing from graph.
# From (27, 25), observed edge ((15, 12), (15, 13)) is blocked. Removing from graph.
# From (27, 25), observed edge ((16, 12), (16, 13)) is blocked. Removing from graph.
# From (27, 25), observed edge ((11, 11), (10, 11)) is blocked. Removing from graph.
# From (27, 25), observed edge ((12, 12), (12, 13)) is blocked. Removing from graph.
# From (27, 25), observed edge ((11, 11), (11, 12)) is blocked. Removing from graph.
# From (27, 25), observed edge ((13, 10), (14, 10)) is blocked. Removing from graph.
# From (27, 25), observed edge ((14, 11), (14, 10)) is blocked. Removing from graph.
# From (27, 25), observed edge ((13, 13), (12, 13)) is blocked. Removing from graph.
# From (27, 25), observed edge ((17, 13), (17, 14)) is blocked. Removing from graph.
# From (27, 25), observed edge ((16, 13), (16, 12)) is blocked. Removing from graph.
# From (27, 25), observed edge ((12, 11), (12, 12)) is blocked. Removing from graph.
# From (27, 25), observed edge ((17, 14), (17, 15)) is blocked. Removing from graph.
# From (27, 25), observed edge ((12, 12), (11, 12)) is blocked. Removing from graph.
# From (27, 25), observed edge ((15, 12), (14, 12)) is blocked. Removing from graph.
# From (27, 25), observed edge ((18, 14), (17, 14)) is blocked. Removing from graph.
# From (27, 25), observed edge ((17, 15), (17, 14)) is blocked. Removing from graph.
# From (27, 25), observed edge ((17, 14), (16, 14)) is blocked. Removing from graph.
# From (27, 25), observed edge ((11, 12), (12, 12)) is blocked. Removing from graph.
# From (27, 25), observed edge ((12, 12), (13, 12)) is blocked. Removing from graph.
# From (27, 25), observed edge ((11, 11), (12, 11)) is blocked. Removing from graph.
# From (27, 25), observed edge ((11, 10), (11, 11)) is blocked. Removing from graph.
# From (27, 25), observed edge ((12, 11), (11, 11)) is blocked. Removing from graph.
# From (27, 25), observed edge ((16, 13), (16, 14)) is blocked. Removing from graph.
# From (27, 25), observed edge ((14, 14), (13, 14)) is blocked. Removing from graph.
# From (27, 25), observed edge ((11, 12), (11, 11)) is blocked. Removing from graph.
# From (27, 25), observed edge ((12, 12), (12, 11)) is blocked. Removing from graph.
# From (27, 25), observed edge ((15, 12), (15, 11)) is blocked. Removing from graph.
# From (27, 25), observed edge ((15, 12), (16, 12)) is blocked. Removing from graph.
# From (27, 25), observed edge ((11, 11), (11, 10)) is blocked. Removing from graph.
# From (27, 25), observed edge ((12, 13), (13, 13)) is blocked. Removing from graph.
# Moving from (27, 25) to (27, 24)
# From (27, 24), observed edge ((15, 15), (14, 15)) is blocked. Removing from graph.
# From (27, 24), observed edge ((14, 15), (15, 15)) is blocked. Removing from graph.
# From (27, 24), observed edge ((14, 14), (14, 15)) is blocked. Removing from graph.
# From (27, 24), observed edge ((14, 15), (14, 14)) is blocked. Removing from graph.
# Moving from (27, 24) to (27, 23)
# Moving from (27, 23) to (27, 22)
# Moving from (27, 22) to (27, 21)
# Moving from (27, 21) to (26, 21)
# Moving from (26, 21) to (25, 21)
# Moving from (25, 21) to (25, 20)
# Moving from (25, 20) to (24, 20)
# Moving from (24, 20) to (23, 20)
# Moving from (23, 20) to (23, 19)
# Moving from (23, 19) to (22, 19)
# Moving from (22, 19) to (22, 18)
# Moving from (22, 18) to (22, 17)
# Moving from (22, 17) to (22, 16)
# Moving from (22, 16) to (22, 15)
# Moving from (22, 15) to (22, 14)
# Moving from (22, 14) to (23, 14)
# Moving from (23, 14) to (23, 13)
# From (23, 13), observed edge ((16, 11), (15, 11)) is blocked. Removing from graph.
# From (23, 13), observed edge ((16, 11), (16, 12)) is blocked. Removing from graph.
# From (23, 13), observed edge ((15, 11), (16, 11)) is blocked. Removing from graph.
# From (23, 13), observed edge ((15, 11), (15, 10)) is blocked. Removing from graph.
# From (23, 13), observed edge ((16, 12), (16, 11)) is blocked. Removing from graph.
# From (23, 13), observed edge ((17, 12), (16, 12)) is blocked. Removing from graph.
# From (23, 13), observed edge 
# Moving from (12, 46) to (13, 46)
# Moving from (13, 46) to (14, 46)
# Moving from (14, 46) to (14, 47)
# Moving from (14, 47) to (14, 48)
# Moving from (14, 48) to (14, 49)
# Moving from (14, 49) to (14, 50)
# Moving from (14, 50) to (14, 51)
# Moving from (14, 51) to (14, 52)
# Moving from (14, 52) to (14, 53)
# Moving from (14, 53) to (14, 54)

# %%
# --- Grid spacing (64x64 grid) ---
xs = sorted(set(p[0] for p in pos.values()))
ys = sorted(set(p[1] for p in pos.values()))
cell_w = xs[1] - xs[0]
cell_h = ys[1] - ys[0]

fig, ax = plt.subplots(figsize=(10, 10))

# --- Terrain squares (obstacles black; everything else height-coloured) ---
for node, data in blocked_env_graph.nodes(data=True):
    x, y = pos[node]
    if data.get("type") == "obstacle":
        color = "black"
    else:
        color = cmap(norm(data.get('height', 0)))
    ax.add_patch(patches.Rectangle(
        (x - cell_w / 2, y - cell_h / 2), cell_w, cell_h,
        linewidth=0, facecolor=color
    ))

# Colorbar
sm = plt.cm.ScalarMappable(cmap=cmap, norm=norm)
sm.set_array([])
cbar = fig.colorbar(sm, ax=ax, fraction=0.046, pad=0.04)
cbar.set_label('Height Value', rotation=270, labelpad=15, fontsize=18)
cbar.ax.tick_params(labelsize=18)

# --- Path edges ---
path_2_edges = {tuple(sorted((path_2[i], path_2[i+1])))
                for i in range(len(path_2) - 1)}
path_2_original_edges = {tuple(sorted((path_2_original[i], path_2_original[i+1])))
                for i in range(len(path_2_original) - 1)}

line1_segments = [[pos[u], pos[v]] for u, v in path_1_edges]
dashed_line1_segments = [[pos[u], pos[v]] for u, v in path1_original_edges]
line2_segments = [[pos[u], pos[v]] for u, v in path_2_edges]
dashed_line2_segments = [[pos[u], pos[v]] for u, v in path_2_original_edges]

# SP agent paths (commented out by default; uncomment to overlay)
lc1 = mc.LineCollection(line1_segments, colors='blue', linewidths=5.0, zorder=3)
# ax.add_collection(lc1)
dashed_lc1 = mc.LineCollection(dashed_line1_segments, colors='blue', linewidth=5.0,
                               zorder=5, linestyles='dotted')
# ax.add_collection(dashed_lc1)

ax.add_collection(mc.LineCollection(line2_segments, colors='red', linewidths=5.0, zorder=3))
ax.add_collection(mc.LineCollection(dashed_line2_segments, colors='green', linewidth=3.0,
                                    zorder=5, linestyles='dotted'))

# --- Source / target markers (reads agent's view env_graph2 so reached targets show grey) ---
src_pts, unreached_pts, reached_pts = [], [], []
for node, data in env_graph2.nodes(data=True):
    t = data.get("type")
    if t == "source":
        src_pts.append(pos[node])
    elif t == "target_unreached":
        unreached_pts.append(pos[node])
    elif t == "target_reached":
        reached_pts.append(pos[node])

if src_pts:
    ax.scatter([p[0] for p in src_pts], [p[1] for p in src_pts],
               marker='o', s=220, facecolor='limegreen', edgecolor='darkgreen',
               linewidths=1.5, zorder=10)
if unreached_pts:
    ax.scatter([p[0] for p in unreached_pts], [p[1] for p in unreached_pts],
               marker='x', s=200, color='red', linewidths=3, zorder=10)
if reached_pts:
    ax.scatter([p[0] for p in reached_pts], [p[1] for p in reached_pts],
               marker='x', s=200, color='grey', linewidths=3, zorder=10)

# --- Fit axes tightly to the grid ---
ax.set_xlim(xs[0] - cell_w / 2, xs[-1] + cell_w / 2)
ax.set_ylim(ys[0] - cell_h / 2, ys[-1] + cell_h / 2)
ax.set_aspect('equal')
ax.axis('off')

plt.tight_layout()
plt.show()

# --- Path length ---
total_path_length = 0.0
for i in range(len(path_2) - 1):
    u = path_2[i]
    v = path_2[i + 1]
    edge_data = blocked_env_graph.get_edge_data(u, v)
    if edge_data:
        total_path_length += edge_data.get('distance', 0.0)
print(f"Total path length taken by the agent: {total_path_length:.2f}")

# %% [markdown]
# Let's also create an interactive version of the map

# %%
import plotly.graph_objects as go

def plot_interactive_env_graph(env_graph, observer_node=None):
    # 1. Prepare Positions and Visibility
    pos = nx.get_node_attributes(env_graph, 'pos')
    
    # Standardize visible edges for lookup
    visible_set = set()
    if observer_node and "visible_edges" in env_graph.nodes[observer_node]:
        visible_set = set(tuple(sorted(e)) for e in env_graph.nodes[observer_node]["visible_edges"])

    # 2. Build Edge Traces (Gray for hidden, Gold for visible)
    # We split them into two traces so they can be toggled in the legend
    edge_x_hidden, edge_y_hidden = [], []
    edge_x_visible, edge_y_visible = [], []

    for u, v in env_graph.edges():
        x0, y0 = pos[u]
        x1, y1 = pos[v]
        edge_key = tuple(sorted((u, v)))
        
        if edge_key in visible_set:
            edge_x_visible.extend([x0, x1, None])
            edge_y_visible.extend([y0, y1, None])
        else:
            edge_x_hidden.extend([x0, x1, None])
            edge_y_hidden.extend([y0, y1, None])

    # 3. Build Node Traces
    node_x, node_y = [], []
    node_color, node_text, node_size = [], [], []

    for node, data in env_graph.nodes(data=True):
        x, y = pos[node]
        node_x.append(x)
        node_y.append(y)
        
        # Metadata for Hover
        h = data.get('height', 0)
        dist_info = "" # You could add sum of edge weights here
        node_text.append(f"Node: {node}<br>Height: {h:.2f}<br>Type: {data.get('type')}")

        # Color Logic
        if data.get("type") == "source":
            node_color.append('limegreen')
            node_size.append(15)
        elif data.get("type") == "target":
            node_color.append('cyan')
            node_size.append(15)
        else:
            # Using Plotly's internal terrain-like colorscale (Earth)
            node_color.append(h) 
            node_size.append(8)

    # 4. Create the Figure
    fig = go.Figure()

    # Add Hidden Edges
    fig.add_trace(go.Scatter(
        x=edge_x_hidden, y=edge_y_hidden,
        line=dict(width=0.5, color='#888'),
        hoverinfo='none', mode='lines', name='Hidden Edges'
    ))

    # Add Visible Edges (Gold)
    fig.add_trace(go.Scatter(
        x=edge_x_visible, y=edge_y_visible,
        line=dict(width=2, color='gold'),
        hoverinfo='none', mode='lines', name='Visible from Observer'
    ))

    # Add Nodes
    fig.add_trace(go.Scatter(
        x=node_x, y=node_y,
        mode='markers',
        name='Terrain Nodes',
        marker=dict(
            showscale=True,
            colorscale='Earth',
            color=node_color,
            size=node_size,
            colorbar=dict(title='Height', thickness=15, x=1.02),
            line_width=1
        ),
        text=node_text,
        hoverinfo='text'
    ))

    # Layout tweaks
    fig.update_layout(
        title=f"Interactive Terrain Graph",
        showlegend=True,
        hovermode='closest',
        margin=dict(b=20, l=5, r=5, t=40),
        xaxis=dict(showgrid=False, zeroline=False, showticklabels=False),
        yaxis=dict(showgrid=False, zeroline=False, showticklabels=False),
        plot_bgcolor='white'
    )

    return fig

# --- Execution ---
fig = plot_interactive_env_graph(env_graph)
fig.show(renderer="browser")
